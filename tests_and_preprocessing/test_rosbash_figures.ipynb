# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from matplotlib import ticker
import pandas as pd
import scanpy as sc
import seaborn as sns
import re
from copy import deepcopy
import matplotlib.image as mpimg
from old_dataset_handler import df_to_anndata, anndata_to_df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DIP_df = pd.read_csv('data_subsets/DIP_drp.csv', index_col=0)
DIP_df_bk = deepcopy(DIP_df)
DIP_ad = df_to_anndata(DIP_df)
DIP_ad_bk = deepcopy(DIP_ad)
print(DIP_ad)
DIP_df.head(10)
# Out:
# AnnData object with n_obs × n_vars = 2615 × 5
#     obs: 'Idents', 'date', 'experiment', 'exp_time'
#     var: 0
#                                      DIP-gamma  DIP-beta  DIP-delta  \
# 20190528_CLK856_DD_CT02_AR05_ACAGAC          0         1          2
# 20190528_CLK856_DD_CT02_AR05_ACTCGA          0         0          1
# 20190528_CLK856_DD_CT02_AR05_AGACCA          0         0          1
# 20190528_CLK856_DD_CT02_AR05_AGGAAG          0         3          1
# 20190528_CLK856_DD_CT02_AR05_CATGCA          1        13          0
# 20190528_CLK856_DD_CT02_AR05_CTAGTG          0         0          3
# 20190528_CLK856_DD_CT02_AR05_GAAGTG          1         0          2
# 20190528_CLK856_DD_CT02_AR05_GACAAC          0         0          3
# 20190528_CLK856_DD_CT02_AR05_GACAGA          0         1          2
# 20190528_CLK856_DD_CT02_AR05_GAGTAC          0         0          0
#
#                                      DIP-theta  dpr8        Idents  \
# 20190528_CLK856_DD_CT02_AR05_ACAGAC          0    27        6:DN1p
# 20190528_CLK856_DD_CT02_AR05_ACTCGA          0    13        19:DN2
# 20190528_CLK856_DD_CT02_AR05_AGACCA          0     7  15:DN1p_CNMa
# 20190528_CLK856_DD_CT02_AR05_AGGAAG          0     7        19:DN2
# 20190528_CLK856_DD_CT02_AR05_CATGCA          1     7        3:DN1a
# 20190528_CLK856_DD_CT02_AR05_CTAGTG          1     2       2:s_LNv
# 20190528_CLK856_DD_CT02_AR05_GAAGTG          3    19        7:DN1p
# 20190528_CLK856_DD_CT02_AR05_GACAAC          0    13       2:s_LNv
# 20190528_CLK856_DD_CT02_AR05_GACAGA          2     3       18:DN1p
# 20190528_CLK856_DD_CT02_AR05_GAGTAC          0    15     9:LNd_NPF
#
#                                            date experiment exp_time
# 20190528_CLK856_DD_CT02_AR05_ACAGAC  2019-05-28         DD     CT02
# 20190528_CLK856_DD_CT02_AR05_ACTCGA  2019-05-28         DD     CT02
# 20190528_CLK856_DD_CT02_AR05_AGACCA  2019-05-28         DD     CT02
# 20190528_CLK856_DD_CT02_AR05_AGGAAG  2019-05-28         DD     CT02
# 20190528_CLK856_DD_CT02_AR05_CATGCA  2019-05-28         DD     CT02
# 20190528_CLK856_DD_CT02_AR05_CTAGTG  2019-05-28         DD     CT02
# 20190528_CLK856_DD_CT02_AR05_GAAGTG  2019-05-28         DD     CT02
# 20190528_CLK856_DD_CT02_AR05_GACAAC  2019-05-28         DD     CT02
# 20190528_CLK856_DD_CT02_AR05_GACAGA  2019-05-28         DD     CT02
# 20190528_CLK856_DD_CT02_AR05_GAGTAC  2019-05-28         DD     CT02

# %%
idents = [ident for ident in DIP_ad.obs['Idents'].unique()]
idents.sort(key= lambda x : int(x.split(':')[0]))
for ident in idents:
    print(ident)
# Out:
# 1:DN1p_CNMa
# 2:s_LNv
# 3:DN1a
# 4:DN1p
# 5:LNd_Trissin
# 6:DN1p
# 7:DN1p
# 8:LN_ITP
# 9:LNd_NPF
# 12:LNd
# 14:DN3
# 15:DN1p_CNMa
# 18:DN1p
# 19:DN2
# 20:DN3
# 25:l_LNv
# 29:LPN

# %% [markdown]
# ### Part 1: Dot plots

# %%
DIP_ad = deepcopy(DIP_ad_bk)
fig, axs = plt.subplots(1, 2, figsize=(10, 5), gridspec_kw={'width_ratios': [1, 2]})
fig6_B = mpimg.imread('fig6_B.png')
reorder = ["19:DN2", "6:DN1p", "7:DN1p", "29:LPN", "14:DN3", "20:DN3", "4:DN1p",
           "3:DN1a", "15:DN1p_CNMa", "1:DN1p_CNMa", "18:DN1p",
           "12:LNd", "9:LNd_NPF","5:LNd_Trissin", "8:LN_ITP", "25:l_LNv", "2:s_LNv"]
dotplot = sc.pl.DotPlot(DIP_ad,
                        var_names=DIP_ad.var_names,
                        groupby='Idents',
                        categories_order=reorder,
                        standard_scale='var',
                        vmin=-1,
                        vmax=1,
                        var_group_rotation=0.,
                        edgecolors=None,
                        mean_only_expressed=True,
                        title='DIP family gene expression by cluster',
                        cmap='Reds',
                        linewidth=0.,
                        ax=axs[0],)
dotplot.DEFAULT_CATEGORY_WIDTH = 0.7
dotplot.DEFAULT_CATEGORY_HEIGHT = 0.4
dotplot.DEFAULT_PLOT_Y_PADDING = 2
axs[1].imshow(fig6_B)
axs[1].axis('off')
dotplot.show()

# %% [markdown]
# ### Part 2: Scatter plots for single gene

# %%
# retrieve original data and preprocess it
DIP_ad = deepcopy(DIP_ad_bk)
sc.pp.normalize_total(DIP_ad, target_sum=1e4, exclude_highly_expressed=True)
DIP_df = anndata_to_df(DIP_ad)

# remove CT/ZT and just keep the time
DIP_df['time'] = DIP_df['exp_time'].apply(lambda x : x[2:])
# Out:
# C:\Users\gonza\miniconda3\envs\psivenv\Lib\site-packages\scanpy\preprocessing\_normalization.py:234: UserWarning: Some cells have zero counts
#   warn(UserWarning("Some cells have zero counts"))

# %%
# plot with seaborn
gene = 'DIP-beta'
cluster = '2:s_LNv'
sns.set_palette('deep')
gene_palette = {"LD": 'turquoise', "DD": 'gray'}
fig6_D = mpimg.imread('fig6_D.png')


fig, axs = plt.subplots(1, 2, figsize=(8, 4))
axs[0].yaxis.set_major_formatter(ticker.EngFormatter())
axs[0].set_title(f"{gene} {cluster}", fontweight='semibold')
axs[1].imshow(fig6_D, interpolation='nearest', aspect='auto')
axs[1].axis('off')

sns.pointplot(DIP_df[DIP_df['Idents']==cluster],
              x='time',
              y=gene,
              hue='experiment', 
              estimator='mean',
              errorbar='se',
              palette=gene_palette,
              capsize=0.2,
              linewidth=1.5,
              ax=axs[0])
plt.show()

# %% [markdown]
# ### Part 3: cluster heatmaps

# %%
DIP_df = deepcopy(DIP_df_bk)
DIP_df_sLNv = DIP_df[(DIP_df['Idents']=='2:s_LNv') 
                     & (DIP_df['experiment']=='DD')]\
                    .drop(['Idents', 'experiment'], axis=1)
DIP_ad_sLNv = df_to_anndata(DIP_df_sLNv)
DIP_df_sLNv
# Out:
#                                      DIP-gamma  DIP-beta  DIP-delta  \
# 20190528_CLK856_DD_CT02_AR05_CTAGTG          0         0          3
# 20190528_CLK856_DD_CT02_AR05_GACAAC          0         0          3
# 20190528_CLK856_DD_CT02_AR06_ACCAGA          0         0          9
# 20190528_CLK856_DD_CT02_AR07_CAGAAG          0         0          3
# 20190528_CLK856_DD_CT02_AR07_GAGTAC          7         3          4
# ...                                        ...       ...        ...
# 20190704_CLK856_DD_CT22_AR14_ACAGAC          0         0          0
# 20190704_CLK856_DD_CT22_AR14_ACTCTG          0         1          2
# 20190704_CLK856_DD_CT22_AR14_CAACTC          0         0          0
# 20190704_CLK856_DD_CT22_AR14_CATGAG          0         0          1
# 20190704_CLK856_DD_CT22_AR14_CATGTC          0         0          5
#
#                                      DIP-theta  dpr8        date exp_time
# 20190528_CLK856_DD_CT02_AR05_CTAGTG          1     2  2019-05-28     CT02
# 20190528_CLK856_DD_CT02_AR05_GACAAC          0    13  2019-05-28     CT02
# 20190528_CLK856_DD_CT02_AR06_ACCAGA          0    11  2019-05-28     CT02
# 20190528_CLK856_DD_CT02_AR07_CAGAAG          1     9  2019-05-28     CT02
# 20190528_CLK856_DD_CT02_AR07_GAGTAC          1    38  2019-05-28     CT02
# ...                                        ...   ...         ...      ...
# 20190704_CLK856_DD_CT22_AR14_ACAGAC          1     0  2019-07-04     CT22
# 20190704_CLK856_DD_CT22_AR14_ACTCTG          0     0  2019-07-04     CT22
# 20190704_CLK856_DD_CT22_AR14_CAACTC          0     0  2019-07-04     CT22
# 20190704_CLK856_DD_CT22_AR14_CATGAG          0     1  2019-07-04     CT22
# 20190704_CLK856_DD_CT22_AR14_CATGTC          0     1  2019-07-04     CT22
#
# [142 rows x 7 columns]

# %%
sc.pl.heatmap(DIP_ad_sLNv, var_names=DIP_ad_sLNv.var_names, groupby=)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sc.pl.heatmap(DIP_ad_sLNv, var_names=DIP_ad_sLNv.var_names, groupby=None)
#       2 plt.show()
#
# File ~\miniconda3\envs\psivenv\Lib\site-packages\legacy_api_wrap\__init__.py:80, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      77 @wraps(fn)
#      78 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      79     if len(args_all) <= n_positional:
# ---> 80         return fn(*args_all, **kw)
#      82     args_pos: P.args
#      83     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File ~\miniconda3\envs\psivenv\Lib\site-packages\scanpy\plotting\_anndata.py:1136, in heatmap(adata, var_names, groupby, use_raw, log, num_categories, dendrogram, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, standard_scale, swap_axes, show_gene_labels, show, save, figsize, vmin, vmax, vcenter, norm, **kwds)
#    1086 """\
#    1087 Heatmap of the expression values of genes.
#    1088
#    (...)
#    1130 tl.rank_genes_groups
#    1131 """
#    1132 var_names, var_group_labels, var_group_positions = _check_var_names_type(
#    1133     var_names, var_group_labels, var_group_positions
#    1134 )
# -> 1136 categories, obs_tidy = _prepare_dataframe(
#    1137     adata,
#    1138     var_names,
#    1139     groupby,
#    1140     use_raw=use_raw,
#    1141     log=log,
#    1142     num_categories=num_categories,
#    1143     gene_symbols=gene_symbols,
#    1144     layer=layer,
#    1145 )
#    1147 # check if var_group_labels are a subset of categories:
#    1148 if var_group_labels is not None:
#
# File ~\miniconda3\envs\psivenv\Lib\site-packages\scanpy\plotting\_anndata.py:2072, in _prepare_dataframe(adata, var_names, groupby, use_raw, log, num_categories, layer, gene_symbols)
#    2070     groupby = groupby.copy()  # copy to not modify user passed parameter
#    2071     groupby.remove(groupby_index)
# -> 2072 keys = list(groupby) + list(np.unique(var_names))
#    2073 obs_tidy = get.obs_df(
#    2074     adata, keys=keys, layer=layer, use_raw=use_raw, gene_symbols=gene_symbols
#    2075 )
#    2076 assert np.all(np.array(keys) == np.array(obs_tidy.columns))
#
# TypeError: 'NoneType' object is not iterable
