# %% [markdown]
# # Make heatmaps by clusters

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'data_subsets/DIP_drp.csv', index_col=0)
df
# Out:
#                                      DIP-gamma  DIP-beta  ...  experiment  exp_time
# 20190528_CLK856_DD_CT02_AR05_ACAGAC          0         1  ...          DD      CT02
# 20190528_CLK856_DD_CT02_AR05_ACTCGA          0         0  ...          DD      CT02
# 20190528_CLK856_DD_CT02_AR05_AGACCA          0         0  ...          DD      CT02
# 20190528_CLK856_DD_CT02_AR05_AGGAAG          0         3  ...          DD      CT02
# 20190528_CLK856_DD_CT02_AR05_CATGCA          1        13  ...          DD      CT02
# ...                                        ...       ...  ...         ...       ...
# 20190309_CLK856_LD_ZT22_AR02_TCGACA          0         0  ...          LD      ZT22
# 20190309_CLK856_LD_ZT22_AR02_TCGATC          0         7  ...          LD      ZT22
# 20190309_CLK856_LD_ZT22_AR02_TCTGAG          1         3  ...          LD      ZT22
# 20190309_CLK856_LD_ZT22_AR02_TGCAAC          0         0  ...          LD      ZT22
# 20190309_CLK856_LD_ZT22_AR02_TGTCAC          0         0  ...          LD      ZT22
#
# [2615 rows x 9 columns]

# %%
LNV_df = df[df['Idents'] == '2:s_LNv'].drop(['Idents', 'date', 'experiment', 'exp_time'], axis='columns')
LNV_df
# Out:
#                                      DIP-gamma  DIP-beta  ...  DIP-theta  dpr8
# 20190528_CLK856_DD_CT02_AR05_CTAGTG          0         0  ...          1     2
# 20190528_CLK856_DD_CT02_AR05_GACAAC          0         0  ...          0    13
# 20190528_CLK856_DD_CT02_AR06_ACCAGA          0         0  ...          0    11
# 20190528_CLK856_DD_CT02_AR07_CAGAAG          0         0  ...          1     9
# 20190528_CLK856_DD_CT02_AR07_GAGTAC          7         3  ...          1    38
# ...                                        ...       ...  ...        ...   ...
# 20190309_CLK856_LD_ZT22_AR02_ACTCAC          0         2  ...          0     0
# 20190309_CLK856_LD_ZT22_AR02_AGGAAG          0         0  ...          0     4
# 20190309_CLK856_LD_ZT22_AR02_AGGACA          1         0  ...          0     0
# 20190309_CLK856_LD_ZT22_AR02_GACATG          0         0  ...          0     2
# 20190309_CLK856_LD_ZT22_AR02_TCGACA          0         0  ...          0     8
#
# [323 rows x 5 columns]

# %%
sns.heatmap(LNV_df)
# Out:
# <Axes: >
